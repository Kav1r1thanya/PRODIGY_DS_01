# %%
import matplotlib.pyplot as plt

ages = [25, 88, 59, 40, 28, 14, 44, 64, 88, 70, 8, 87, 0, 7, 87, 62, 10, 80, 7, 34, 34, 32, 4, 40, 27, 6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36, 98, 43, 85, 90, 34, 64, 98, 100, 46, 77, 2, 0, 4, 89, 13, 26, 8, 78, 14, 89, 41, 76, 50, 62, 95, 51, 95, 3, 93, 100, 22, 14, 42, 28, 35, 12, 31, 70, 58, 85, 27, 65, 41, 44, 61, 56, 5, 27, 27, 43, 83, 29, 61, 74, 91, 88, 61, 96, 0, 26, 61, 76, 2, 72]

plt.hist(ages, bins=20, edgecolor='black')

plt.title('Distribution of ages of 100 people in an apartment(population)')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %%
import matplotlib.pyplot as plt

genders=['female', 'male', 'trans', 'agender', 'pan', 'queer', 'unidentified']
headcount= [37,31,7,1,3,2,19]

plt.bar(genders,headcount)

plt.title('Distribution of gender of 100 people in an apartment(population)')
plt.xlabel('genders')
plt.ylabel('headcount')

plt.show()
